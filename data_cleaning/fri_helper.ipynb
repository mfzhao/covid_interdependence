# %%
library(dplyr)
library(stringr)
library(readr)
library(tidyr)
library(lfe)
library(glmnet)
library(aod)
library(xgboost)
library(doMC)
registerDoMC(20)
source('~/covid_mobility/paper_code/utils/residualizer+genAlters.R')

# %%
load('/nfs/sloanlab004/projects/covid_mobility_proj/data/PROCESSED_DATA/data_pre_residualization.RData')

# %%
panel %>%
    mutate(ash_alter_rnstu   = asinh(alter_rnstu),
           ash_alter_nhd     = asinh(alter_nhd),
           log_alter_mcbgv   = asinh(alter_mcbgv)) -> panel

# %%
panel %>% 
    select(-matches('prcp..'), 
           -matches('tmax..'),
           -matches('_Xsh'), 
           -matches('_Xbg'),
           -device_count,
           -non_home_cbg_visits_within_county,
           -cbg_visits_outside_county,
           -home_cbg_visits,
           -outside_device_county_visits, 
           -ban_gatherings) -> panel

# %%
set.seed(2345)
panel %>%
    ungroup() %>%
    select(county_fips) %>%
    distinct() %>%
    mutate(i = sample(1:n(), n(), replace = F),
            grp = i %% 3 + 1) %>%
    select(-i) -> groups

panel %>%
    left_join(groups) -> panel
# Out:
# Joining, by = "county_fips"

# %%
gen_helper <- function(newPRCP, newTMAX) {
    panel %>%
        mutate(PRCP = newPRCP,
               TMAX = newTMAX,
               PRCP.fe.r = felm(PRCP ~ 0 | county_fips + ds)$resid, 
               TMAX.fe.r = felm(TMAX ~ 0 | county_fips + ds)$resid) -> FRI_df

    FRI_df %>%
        select(ds, county_fips, PRCP.fe.r, TMAX.fe.r, n) %>%
        left_join(groups) -> helper_frame
    return(helper_frame)
}

# %%
FRIresidualizer <- function(Y, colname, helper) {
    helper %>%
        mutate(Y = Y,
               Y.r = felm(Y ~ 0 | county_fips + ds, .)$resid) -> temp_df
    
    dm    <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.fe.r + TMAX.fe.r, temp_df), label = temp_df$Y.r)
    param <- list(max_depth=2, eta=.5, silent=1, objective='reg:linear')
    fit   <- xgb.cv(params = param, 
                    data = dm, 
                    folds = folds,
                    nrounds = 100, 
                    early_stopping_rounds = 3, 
                    weight = temp_df$n)
    best_n <- fit$best_iteration
    for (i in 1:3) {
        tr  <- temp_df %>% filter(grp != i)
        trm <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.fe.r + TMAX.fe.r, tr), label = tr$Y.r)
        fit <- xgb.train(params = param, 
                         data = trm, 
                         nrounds = best_n, 
                         weight = tr$n)
        te  <- temp_df %>% filter(grp == i)
        tem <- xgb.DMatrix(data = model.matrix(~ 0 + PRCP.fe.r + TMAX.fe.r, te), label = te$Y.r)
        te %>%
            select(county_fips, ds) %>%
            mutate(pred = predict(fit, newdata = tem)) -> pred_df
        assign(str_c('temp',i), pred_df)
    }
    out <- bind_rows(temp1, temp2, temp3) %>%
        arrange(ds, county_fips) %>%
        mutate(tempname = temp_df$Y.r - pred) %>%
        select(-pred, -ds, -county_fips)
    colnames(out) <- str_c(colname, '.r')
    return(out)
}

# %%
gen_FRI_data <- function(newPRCP, newTMAX) {
    panel %>%
        mutate(PRCP = newPRCP,
               TMAX = newTMAX,
               PRCP.fe.r = felm(PRCP ~ 0 | county_fips + ds)$resid, 
               TMAX.fe.r = felm(TMAX ~ 0 | county_fips + ds)$resid) %>%
        mutate(rain = as.numeric(PRCP > 0)) %>%     ## feel free to add instruments here
        mutate(alter_rain = weightedAlters(., WM, rain)) -> FRI_df
    ## due to how weightedAlters works, it cannot be in same mutate that the base variable was created in

    FRI_df %>%
        select(ds, county_fips, PRCP.fe.r, TMAX.fe.r, n, grp) %>%
        left_join(groups) -> helper_frame
    
    FRI_df %>% 
        select(-ds, 
               -county_fips, 
               -state_abbv, 
               -n, 
               -PRCP, 
               -TMAX, 
               -PRCP.fe.r, 
               -TMAX.fe.r, 
               -grp) %>%
        colnames() -> cols_to_xgr
    print(cols_to_xgr)
    
    xg.residuals <- foreach(i = 1:length(cols_to_xgr), .combine = cbind) %do% 
        FRIresidualizer(FRI_df[[cols_to_xgr[i]]], cols_to_xgr[i], helper_frame)
    FRI_df %>%
        bind_cols(xg.residuals) -> FRI_df
    return(FRI_df)   
}

# %%
### Generate New FRI-ed Df
### inputs are vectors that require the observations be in the following order:
### date1, county1, ...
### date1, county2, ...
### ...
### date2, county1, ...
### date2, county2, ...
FRI <- gen_FRI_data(panel$PRCP, panel$TMAX)
# Out:
# Joining, by = c("county_fips", "grp")
#  [1] "sg_nhd"          "stay_home"       "n11"             "n21"
#  [5] "n22"             "n23"             "n31"             "n32"
#  [9] "n33"             "n42"             "n44"             "n45"
# [13] "n48"             "n49"             "n51"             "n52"
# [17] "n53"             "n54"             "n55"             "n56"
# [21] "n61"             "n62"             "n71"             "n72"
# [25] "n81"             "n92"             "nNA"             "fb_btvrc"
# [29] "fb_rnstu"        "sg_mcbgv"        "ban_gmr"         "log_mcbgv"
# [33] "ash_nhd"         "ash_rnstu"       "alter_n11"       "alter_n21"
# [37] "alter_n22"       "alter_n23"       "alter_n31"       "alter_n32"
# [41] "alter_n33"       "alter_n42"       "alter_n44"       "alter_n45"
# [45] "alter_n48"       "alter_n49"       "alter_n51"       "alter_n52"
# [49] "alter_n53"       "alter_n54"       "alter_n55"       "alter_n56"
# [53] "alter_n61"       "alter_n62"       "alter_n71"       "alter_n72"
# [57] "alter_n81"       "alter_n92"       "alter_log_mcbgv" "alter_ash_nhd"
# [61] "alter_ash_rnstu" "alter_nhd"       "alter_mcbgv"     "alter_rnstu"
# [65] "alter_btvrc"     "alter_sh"        "alter_bg"        "alter_bgmr"
# [69] "geo_alter_sh"    "geo_alter_bg"    "geo_alter_bgmr"  "ash_alter_rnstu"
# [73] "ash_alter_nhd"   "log_alter_mcbgv" "rain"            "alter_rain"
# [1]	train-rmse:0.252465+0.000291	test-rmse:0.252463+0.001321
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.129630+0.000209	test-rmse:0.129651+0.001644
# [3]	train-rmse:0.070919+0.000192	test-rmse:0.070995+0.001806
# [4]	train-rmse:0.045486+0.000230	test-rmse:0.045747+0.001649
# [5]	train-rmse:0.036335+0.000280	test-rmse:0.036702+0.001349
# [6]	train-rmse:0.033589+0.000290	test-rmse:0.034077+0.001023
# [7]	train-rmse:0.032805+0.000313	test-rmse:0.033341+0.000809
# [8]	train-rmse:0.032517+0.000292	test-rmse:0.033144+0.000744
# [9]	train-rmse:0.032365+0.000268	test-rmse:0.033129+0.000706
# [10]	train-rmse:0.032252+0.000271	test-rmse:0.033125+0.000643
# [11]	train-rmse:0.032164+0.000327	test-rmse:0.033186+0.000711
# [12]	train-rmse:0.032094+0.000328	test-rmse:0.033171+0.000697
# [13]	train-rmse:0.032041+0.000340	test-rmse:0.033178+0.000698
# Stopping. Best iteration:
# [10]	train-rmse:0.032252+0.000271	test-rmse:0.033125+0.000643
#
# [1]	train-rmse:0.296976+0.000304	test-rmse:0.297969+0.002162
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.198882+0.000328	test-rmse:0.200566+0.001802
# [3]	train-rmse:0.164432+0.000391	test-rmse:0.166794+0.000561
# [4]	train-rmse:0.153780+0.000421	test-rmse:0.156853+0.000162
# [5]	train-rmse:0.150303+0.000450	test-rmse:0.153896+0.000455
# [6]	train-rmse:0.149082+0.000353	test-rmse:0.152998+0.000484
# [7]	train-rmse:0.148304+0.000650	test-rmse:0.152668+0.000633
# [8]	train-rmse:0.147942+0.000637	test-rmse:0.152698+0.000539
# [9]	train-rmse:0.147486+0.000626	test-rmse:0.152887+0.000497
# [10]	train-rmse:0.147165+0.000881	test-rmse:0.152798+0.000425
# Stopping. Best iteration:
# [7]	train-rmse:0.148304+0.000650	test-rmse:0.152668+0.000633
#
# [1]	train-rmse:0.250150+0.000002	test-rmse:0.250150+0.000007
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125150+0.000001	test-rmse:0.125150+0.000008
# [3]	train-rmse:0.062613+0.000000	test-rmse:0.062613+0.000008
# [4]	train-rmse:0.031326+0.000000	test-rmse:0.031326+0.000008
# [5]	train-rmse:0.015675+0.000000	test-rmse:0.015675+0.000008
# [6]	train-rmse:0.007847+0.000001	test-rmse:0.007847+0.000008
# [7]	train-rmse:0.003936+0.000002	test-rmse:0.003936+0.000008
# [8]	train-rmse:0.001988+0.000004	test-rmse:0.001988+0.000008
# [9]	train-rmse:0.001032+0.000007	test-rmse:0.001032+0.000013
# [10]	train-rmse:0.000586+0.000013	test-rmse:0.000586+0.000024
# [11]	train-rmse:0.000403+0.000019	test-rmse:0.000401+0.000036
# [12]	train-rmse:0.000341+0.000022	test-rmse:0.000340+0.000042
# [13]	train-rmse:0.000324+0.000023	test-rmse:0.000322+0.000045
# [14]	train-rmse:0.000319+0.000023	test-rmse:0.000318+0.000046
# [15]	train-rmse:0.000318+0.000024	test-rmse:0.000317+0.000046
# [16]	train-rmse:0.000318+0.000023	test-rmse:0.000316+0.000046
# [17]	train-rmse:0.000318+0.000023	test-rmse:0.000316+0.000046
# [18]	train-rmse:0.000318+0.000023	test-rmse:0.000316+0.000046
# [19]	train-rmse:0.000318+0.000023	test-rmse:0.000316+0.000046
# Stopping. Best iteration:
# [16]	train-rmse:0.000318+0.000023	test-rmse:0.000316+0.000046
#
# [1]	train-rmse:0.250151+0.000000	test-rmse:0.250149+0.000000
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125150+0.000000	test-rmse:0.125150+0.000001
# [3]	train-rmse:0.062613+0.000000	test-rmse:0.062613+0.000001
# [4]	train-rmse:0.031325+0.000000	test-rmse:0.031325+0.000001
# [5]	train-rmse:0.015672+0.000000	test-rmse:0.015672+0.000001
# [6]	train-rmse:0.007841+0.000000	test-rmse:0.007841+0.000001
# [7]	train-rmse:0.003923+0.000000	test-rmse:0.003923+0.000001
# [8]	train-rmse:0.001963+0.000000	test-rmse:0.001963+0.000001
# [9]	train-rmse:0.000982+0.000000	test-rmse:0.000982+0.000001
# [10]	train-rmse:0.000491+0.000000	test-rmse:0.000492+0.000001
# [11]	train-rmse:0.000246+0.000000	test-rmse:0.000246+0.000001
# [12]	train-rmse:0.000124+0.000000	test-rmse:0.000124+0.000002
# [13]	train-rmse:0.000063+0.000000	test-rmse:0.000063+0.000002
# [14]	train-rmse:0.000034+0.000001	test-rmse:0.000034+0.000003
# [15]	train-rmse:0.000021+0.000002	test-rmse:0.000021+0.000004
# [16]	train-rmse:0.000017+0.000002	test-rmse:0.000015+0.000006
# [17]	train-rmse:0.000015+0.000003	test-rmse:0.000013+0.000007
# [18]	train-rmse:0.000015+0.000002	test-rmse:0.000013+0.000008
# [19]	train-rmse:0.000015+0.000002	test-rmse:0.000012+0.000009
# [20]	train-rmse:0.000015+0.000002	test-rmse:0.000012+0.000009
# [21]	train-rmse:0.000015+0.000002	test-rmse:0.000012+0.000009
# [22]	train-rmse:0.000015+0.000002	test-rmse:0.000012+0.000008
# [23]	train-rmse:0.000015+0.000002	test-rmse:0.000012+0.000008
# [24]	train-rmse:0.000015+0.000002	test-rmse:0.000012+0.000008
# [25]	train-rmse:0.000015+0.000002	test-rmse:0.000012+0.000008
# Stopping. Best iteration:
# [22]	train-rmse:0.000015+0.000002	test-rmse:0.000012+0.000008
#
# [1]	train-rmse:0.250161+0.000019	test-rmse:0.250161+0.000086
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125171+0.000014	test-rmse:0.125171+0.000100
# [3]	train-rmse:0.062655+0.000018	test-rmse:0.062655+0.000118
# [4]	train-rmse:0.031411+0.000030	test-rmse:0.031410+0.000147
# [5]	train-rmse:0.015842+0.000056	test-rmse:0.015841+0.000200
# [6]	train-rmse:0.008175+0.000107	test-rmse:0.008171+0.000298
# [7]	train-rmse:0.004552+0.000194	test-rmse:0.004534+0.000449
# [8]	train-rmse:0.003004+0.000286	test-rmse:0.002979+0.000607
# [9]	train-rmse:0.002453+0.000349	test-rmse:0.002434+0.000693
# [10]	train-rmse:0.002278+0.000396	test-rmse:0.002276+0.000724
# [11]	train-rmse:0.002226+0.000403	test-rmse:0.002237+0.000725
# [12]	train-rmse:0.002155+0.000447	test-rmse:0.002240+0.000717
# [13]	train-rmse:0.002019+0.000427	test-rmse:0.002328+0.000695
# [14]	train-rmse:0.002001+0.000414	test-rmse:0.002335+0.000687
# Stopping. Best iteration:
# [11]	train-rmse:0.002226+0.000403	test-rmse:0.002237+0.000725
#
# [1]	train-rmse:0.250153+0.000012	test-rmse:0.250153+0.000060
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125157+0.000006	test-rmse:0.125157+0.000066
# [3]	train-rmse:0.062627+0.000002	test-rmse:0.062627+0.000068
# [4]	train-rmse:0.031354+0.000000	test-rmse:0.031354+0.000068
# [5]	train-rmse:0.015731+0.000001	test-rmse:0.015730+0.000067
# [6]	train-rmse:0.007957+0.000004	test-rmse:0.007957+0.000063
# [7]	train-rmse:0.004151+0.000008	test-rmse:0.004151+0.000054
# [8]	train-rmse:0.002374+0.000029	test-rmse:0.002385+0.000036
# [9]	train-rmse:0.001655+0.000042	test-rmse:0.001677+0.000017
# [10]	train-rmse:0.001416+0.000048	test-rmse:0.001446+0.000023
# [11]	train-rmse:0.001346+0.000051	test-rmse:0.001383+0.000034
# [12]	train-rmse:0.001327+0.000052	test-rmse:0.001369+0.000040
# [13]	train-rmse:0.001319+0.000051	test-rmse:0.001368+0.000042
# [14]	train-rmse:0.001314+0.000051	test-rmse:0.001367+0.000045
# [15]	train-rmse:0.001307+0.000053	test-rmse:0.001367+0.000045
# [16]	train-rmse:0.001304+0.000052	test-rmse:0.001369+0.000042
# [17]	train-rmse:0.001301+0.000053	test-rmse:0.001370+0.000041
# [18]	train-rmse:0.001280+0.000043	test-rmse:0.001369+0.000042
# Stopping. Best iteration:
# [15]	train-rmse:0.001307+0.000053	test-rmse:0.001367+0.000045
#
# [1]	train-rmse:0.250166+0.000007	test-rmse:0.250166+0.000033
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125181+0.000006	test-rmse:0.125182+0.000036
# [3]	train-rmse:0.062675+0.000011	test-rmse:0.062675+0.000040
# [4]	train-rmse:0.031451+0.000022	test-rmse:0.031451+0.000051
# [5]	train-rmse:0.015922+0.000044	test-rmse:0.015922+0.000087
# [6]	train-rmse:0.008329+0.000084	test-rmse:0.008328+0.000163
# [7]	train-rmse:0.004816+0.000145	test-rmse:0.004823+0.000276
# [8]	train-rmse:0.003386+0.000199	test-rmse:0.003413+0.000390
# [9]	train-rmse:0.002911+0.000232	test-rmse:0.002951+0.000446
# [10]	train-rmse:0.002755+0.000229	test-rmse:0.002826+0.000459
# [11]	train-rmse:0.002696+0.000233	test-rmse:0.002795+0.000463
# [12]	train-rmse:0.002655+0.000214	test-rmse:0.002785+0.000468
# [13]	train-rmse:0.002639+0.000215	test-rmse:0.002788+0.000474
# [14]	train-rmse:0.002630+0.000213	test-rmse:0.002791+0.000471
# [15]	train-rmse:0.002623+0.000213	test-rmse:0.002793+0.000474
# Stopping. Best iteration:
# [12]	train-rmse:0.002655+0.000214	test-rmse:0.002785+0.000468
#
# [1]	train-rmse:0.250150+0.000003	test-rmse:0.250150+0.000016
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125150+0.000002	test-rmse:0.125150+0.000017
# [3]	train-rmse:0.062613+0.000000	test-rmse:0.062613+0.000018
# [4]	train-rmse:0.031327+0.000000	test-rmse:0.031327+0.000018
# [5]	train-rmse:0.015675+0.000000	test-rmse:0.015676+0.000018
# [6]	train-rmse:0.007848+0.000001	test-rmse:0.007848+0.000018
# [7]	train-rmse:0.003937+0.000002	test-rmse:0.003937+0.000016
# [8]	train-rmse:0.001992+0.000004	test-rmse:0.001991+0.000013
# [9]	train-rmse:0.001039+0.000008	test-rmse:0.001039+0.000011
# [10]	train-rmse:0.000597+0.000013	test-rmse:0.000597+0.000016
# [11]	train-rmse:0.000419+0.000018	test-rmse:0.000418+0.000030
# [12]	train-rmse:0.000360+0.000021	test-rmse:0.000359+0.000040
# [13]	train-rmse:0.000344+0.000022	test-rmse:0.000342+0.000044
# [14]	train-rmse:0.000340+0.000022	test-rmse:0.000338+0.000046
# [15]	train-rmse:0.000339+0.000023	test-rmse:0.000337+0.000047
# [16]	train-rmse:0.000339+0.000023	test-rmse:0.000336+0.000048
# [17]	train-rmse:0.000338+0.000023	test-rmse:0.000336+0.000048
# [18]	train-rmse:0.000338+0.000023	test-rmse:0.000336+0.000048
# [19]	train-rmse:0.000338+0.000023	test-rmse:0.000336+0.000048
# Stopping. Best iteration:
# [16]	train-rmse:0.000339+0.000023	test-rmse:0.000336+0.000048
#
# [1]	train-rmse:0.250153+0.000002	test-rmse:0.250153+0.000008
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125156+0.000002	test-rmse:0.125156+0.000010
# [3]	train-rmse:0.062624+0.000003	test-rmse:0.062624+0.000013
# [4]	train-rmse:0.031349+0.000006	test-rmse:0.031349+0.000018
# [5]	train-rmse:0.015719+0.000013	test-rmse:0.015719+0.000029
# [6]	train-rmse:0.007935+0.000025	test-rmse:0.007935+0.000054
# [7]	train-rmse:0.004108+0.000048	test-rmse:0.004106+0.000100
# [8]	train-rmse:0.002309+0.000087	test-rmse:0.002304+0.000172
# [9]	train-rmse:0.001553+0.000131	test-rmse:0.001550+0.000247
# [10]	train-rmse:0.001289+0.000154	test-rmse:0.001287+0.000290
# [11]	train-rmse:0.001181+0.000163	test-rmse:0.001218+0.000316
# [12]	train-rmse:0.001134+0.000151	test-rmse:0.001197+0.000320
# [13]	train-rmse:0.001111+0.000148	test-rmse:0.001195+0.000324
# [14]	train-rmse:0.001070+0.000118	test-rmse:0.001193+0.000324
# [15]	train-rmse:0.001063+0.000119	test-rmse:0.001198+0.000321
# [16]	train-rmse:0.001060+0.000117	test-rmse:0.001199+0.000320
# [17]	train-rmse:0.001055+0.000114	test-rmse:0.001199+0.000320
# Stopping. Best iteration:
# [14]	train-rmse:0.001070+0.000118	test-rmse:0.001193+0.000324
#
# [1]	train-rmse:0.250158+0.000020	test-rmse:0.250158+0.000101
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125166+0.000009	test-rmse:0.125166+0.000110
# [3]	train-rmse:0.062645+0.000004	test-rmse:0.062645+0.000114
# [4]	train-rmse:0.031389+0.000003	test-rmse:0.031389+0.000115
# [5]	train-rmse:0.015800+0.000006	test-rmse:0.015800+0.000112
# [6]	train-rmse:0.008094+0.000013	test-rmse:0.008094+0.000103
# [7]	train-rmse:0.004404+0.000025	test-rmse:0.004410+0.000082
# [8]	train-rmse:0.002795+0.000041	test-rmse:0.002814+0.000067
# [9]	train-rmse:0.002207+0.000053	test-rmse:0.002240+0.000077
# [10]	train-rmse:0.002027+0.000058	test-rmse:0.002076+0.000098
# [11]	train-rmse:0.001965+0.000047	test-rmse:0.002037+0.000111
# [12]	train-rmse:0.001948+0.000047	test-rmse:0.002028+0.000113
# [13]	train-rmse:0.001939+0.000044	test-rmse:0.002025+0.000114
# [14]	train-rmse:0.001933+0.000046	test-rmse:0.002025+0.000114
# [15]	train-rmse:0.001928+0.000044	test-rmse:0.002027+0.000113
# [16]	train-rmse:0.001923+0.000046	test-rmse:0.002030+0.000116
# [17]	train-rmse:0.001918+0.000047	test-rmse:0.002031+0.000117
# Stopping. Best iteration:
# [14]	train-rmse:0.001933+0.000046	test-rmse:0.002025+0.000114
#
# [1]	train-rmse:0.251197+0.000029	test-rmse:0.251196+0.000016
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.127230+0.000085	test-rmse:0.127230+0.000090
# [3]	train-rmse:0.066672+0.000174	test-rmse:0.066672+0.000259
# [4]	train-rmse:0.038702+0.000303	test-rmse:0.038818+0.000575
# [5]	train-rmse:0.027512+0.000411	test-rmse:0.027727+0.000865
# [6]	train-rmse:0.023850+0.000473	test-rmse:0.024252+0.000985
# [7]	train-rmse:0.022793+0.000488	test-rmse:0.023300+0.001040
# [8]	train-rmse:0.022478+0.000485	test-rmse:0.023044+0.001050
# [9]	train-rmse:0.022330+0.000497	test-rmse:0.023007+0.001057
# [10]	train-rmse:0.022255+0.000517	test-rmse:0.023005+0.001049
# [11]	train-rmse:0.022199+0.000519	test-rmse:0.022989+0.001038
# [12]	train-rmse:0.022154+0.000521	test-rmse:0.023023+0.001050
# [13]	train-rmse:0.022078+0.000489	test-rmse:0.023053+0.001052
# [14]	train-rmse:0.022022+0.000494	test-rmse:0.023065+0.001068
# Stopping. Best iteration:
# [11]	train-rmse:0.022199+0.000519	test-rmse:0.022989+0.001038
#
# [1]	train-rmse:0.250799+0.000150	test-rmse:0.250798+0.000724
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.126441+0.000090	test-rmse:0.126440+0.000805
# [3]	train-rmse:0.065155+0.000084	test-rmse:0.065153+0.000850
# [4]	train-rmse:0.036104+0.000117	test-rmse:0.036128+0.000841
# [5]	train-rmse:0.023749+0.000160	test-rmse:0.023832+0.000794
# [6]	train-rmse:0.019406+0.000184	test-rmse:0.019575+0.000657
# [7]	train-rmse:0.018112+0.000207	test-rmse:0.018351+0.000563
# [8]	train-rmse:0.017700+0.000229	test-rmse:0.018066+0.000467
# [9]	train-rmse:0.017576+0.000223	test-rmse:0.018009+0.000438
# [10]	train-rmse:0.017521+0.000219	test-rmse:0.017994+0.000433
# [11]	train-rmse:0.017477+0.000208	test-rmse:0.017978+0.000416
# [12]	train-rmse:0.017435+0.000212	test-rmse:0.017990+0.000423
# [13]	train-rmse:0.017402+0.000219	test-rmse:0.017996+0.000420
# [14]	train-rmse:0.017357+0.000209	test-rmse:0.017998+0.000405
# Stopping. Best iteration:
# [11]	train-rmse:0.017477+0.000208	test-rmse:0.017978+0.000416
#
# [1]	train-rmse:0.250184+0.000004	test-rmse:0.250185+0.000040
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125219+0.000009	test-rmse:0.125219+0.000033
# [3]	train-rmse:0.062751+0.000025	test-rmse:0.062751+0.000013
# [4]	train-rmse:0.031597+0.000054	test-rmse:0.031594+0.000048
# [5]	train-rmse:0.016205+0.000107	test-rmse:0.016208+0.000150
# [6]	train-rmse:0.008826+0.000176	test-rmse:0.008852+0.000334
# [7]	train-rmse:0.005549+0.000297	test-rmse:0.005674+0.000552
# [8]	train-rmse:0.004344+0.000404	test-rmse:0.004537+0.000707
# [9]	train-rmse:0.003988+0.000441	test-rmse:0.004198+0.000773
# [10]	train-rmse:0.003861+0.000469	test-rmse:0.004115+0.000793
# [11]	train-rmse:0.003793+0.000468	test-rmse:0.004124+0.000768
# [12]	train-rmse:0.003770+0.000472	test-rmse:0.004128+0.000770
# [13]	train-rmse:0.003738+0.000453	test-rmse:0.004134+0.000763
# Stopping. Best iteration:
# [10]	train-rmse:0.003861+0.000469	test-rmse:0.004115+0.000793
#
# [1]	train-rmse:0.250169+0.000011	test-rmse:0.250169+0.000049
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125188+0.000010	test-rmse:0.125189+0.000058
# [3]	train-rmse:0.062689+0.000014	test-rmse:0.062689+0.000070
# [4]	train-rmse:0.031479+0.000025	test-rmse:0.031479+0.000093
# [5]	train-rmse:0.015977+0.000049	test-rmse:0.015977+0.000138
# [6]	train-rmse:0.008434+0.000092	test-rmse:0.008432+0.000221
# [7]	train-rmse:0.004997+0.000150	test-rmse:0.004996+0.000338
# [8]	train-rmse:0.003648+0.000202	test-rmse:0.003658+0.000446
# [9]	train-rmse:0.003215+0.000229	test-rmse:0.003233+0.000492
# [10]	train-rmse:0.003084+0.000234	test-rmse:0.003120+0.000499
# [11]	train-rmse:0.003036+0.000227	test-rmse:0.003098+0.000497
# [12]	train-rmse:0.003000+0.000232	test-rmse:0.003094+0.000490
# [13]	train-rmse:0.002985+0.000225	test-rmse:0.003105+0.000482
# [14]	train-rmse:0.002975+0.000229	test-rmse:0.003107+0.000485
# [15]	train-rmse:0.002953+0.000221	test-rmse:0.003111+0.000488
# Stopping. Best iteration:
# [12]	train-rmse:0.003000+0.000232	test-rmse:0.003094+0.000490
#
# [1]	train-rmse:0.250188+0.000021	test-rmse:0.250188+0.000116
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125227+0.000007	test-rmse:0.125227+0.000122
# [3]	train-rmse:0.062766+0.000011	test-rmse:0.062766+0.000115
# [4]	train-rmse:0.031630+0.000029	test-rmse:0.031630+0.000097
# [5]	train-rmse:0.016273+0.000059	test-rmse:0.016274+0.000077
# [6]	train-rmse:0.008981+0.000111	test-rmse:0.008986+0.000137
# [7]	train-rmse:0.005870+0.000174	test-rmse:0.005892+0.000274
# [8]	train-rmse:0.004756+0.000240	test-rmse:0.004807+0.000374
# [9]	train-rmse:0.004423+0.000252	test-rmse:0.004492+0.000421
# [10]	train-rmse:0.004321+0.000244	test-rmse:0.004423+0.000432
# [11]	train-rmse:0.004276+0.000235	test-rmse:0.004399+0.000445
# [12]	train-rmse:0.004249+0.000248	test-rmse:0.004392+0.000450
# [13]	train-rmse:0.004232+0.000245	test-rmse:0.004404+0.000445
# [14]	train-rmse:0.004219+0.000246	test-rmse:0.004407+0.000445
# [15]	train-rmse:0.004201+0.000254	test-rmse:0.004415+0.000448
# Stopping. Best iteration:
# [12]	train-rmse:0.004249+0.000248	test-rmse:0.004392+0.000450
#
# [1]	train-rmse:0.250187+0.000006	test-rmse:0.250187+0.000028
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125224+0.000005	test-rmse:0.125224+0.000033
# [3]	train-rmse:0.062760+0.000006	test-rmse:0.062760+0.000039
# [4]	train-rmse:0.031619+0.000011	test-rmse:0.031619+0.000049
# [5]	train-rmse:0.016252+0.000020	test-rmse:0.016252+0.000067
# [6]	train-rmse:0.008940+0.000038	test-rmse:0.008948+0.000088
# [7]	train-rmse:0.005797+0.000064	test-rmse:0.005833+0.000129
# [8]	train-rmse:0.004679+0.000082	test-rmse:0.004738+0.000150
# [9]	train-rmse:0.004344+0.000091	test-rmse:0.004422+0.000160
# [10]	train-rmse:0.004248+0.000096	test-rmse:0.004350+0.000171
# [11]	train-rmse:0.004219+0.000099	test-rmse:0.004331+0.000175
# [12]	train-rmse:0.004206+0.000101	test-rmse:0.004325+0.000169
# [13]	train-rmse:0.004195+0.000101	test-rmse:0.004323+0.000174
# [14]	train-rmse:0.004186+0.000100	test-rmse:0.004331+0.000174
# [15]	train-rmse:0.004182+0.000098	test-rmse:0.004332+0.000175
# [16]	train-rmse:0.004173+0.000100	test-rmse:0.004332+0.000175
# Stopping. Best iteration:
# [13]	train-rmse:0.004195+0.000101	test-rmse:0.004323+0.000174
#
# [1]	train-rmse:0.250774+0.000176	test-rmse:0.250774+0.000903
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.126393+0.000076	test-rmse:0.126392+0.000969
# [3]	train-rmse:0.065063+0.000044	test-rmse:0.065061+0.000952
# [4]	train-rmse:0.035944+0.000091	test-rmse:0.035978+0.000862
# [5]	train-rmse:0.023483+0.000136	test-rmse:0.023571+0.000599
# [6]	train-rmse:0.019077+0.000183	test-rmse:0.019262+0.000388
# [7]	train-rmse:0.017759+0.000208	test-rmse:0.018041+0.000328
# [8]	train-rmse:0.017369+0.000199	test-rmse:0.017670+0.000354
# [9]	train-rmse:0.017226+0.000198	test-rmse:0.017599+0.000351
# [10]	train-rmse:0.017167+0.000192	test-rmse:0.017587+0.000378
# [11]	train-rmse:0.017105+0.000197	test-rmse:0.017573+0.000357
# [12]	train-rmse:0.017055+0.000193	test-rmse:0.017585+0.000367
# [13]	train-rmse:0.017016+0.000201	test-rmse:0.017584+0.000383
# [14]	train-rmse:0.016975+0.000199	test-rmse:0.017610+0.000389
# Stopping. Best iteration:
# [11]	train-rmse:0.017105+0.000197	test-rmse:0.017573+0.000357
#
# [1]	train-rmse:0.250161+0.000020	test-rmse:0.250161+0.000095
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125172+0.000011	test-rmse:0.125173+0.000105
# [3]	train-rmse:0.062657+0.000008	test-rmse:0.062658+0.000113
# [4]	train-rmse:0.031415+0.000009	test-rmse:0.031415+0.000120
# [5]	train-rmse:0.015852+0.000015	test-rmse:0.015851+0.000133
# [6]	train-rmse:0.008195+0.000027	test-rmse:0.008193+0.000153
# [7]	train-rmse:0.004584+0.000047	test-rmse:0.004585+0.000184
# [8]	train-rmse:0.003065+0.000069	test-rmse:0.003084+0.000195
# [9]	train-rmse:0.002539+0.000082	test-rmse:0.002570+0.000191
# [10]	train-rmse:0.002375+0.000081	test-rmse:0.002424+0.000178
# [11]	train-rmse:0.002330+0.000085	test-rmse:0.002391+0.000173
# [12]	train-rmse:0.002302+0.000098	test-rmse:0.002383+0.000168
# [13]	train-rmse:0.002295+0.000098	test-rmse:0.002384+0.000164
# [14]	train-rmse:0.002283+0.000106	test-rmse:0.002384+0.000163
# [15]	train-rmse:0.002278+0.000104	test-rmse:0.002387+0.000162
# Stopping. Best iteration:
# [12]	train-rmse:0.002302+0.000098	test-rmse:0.002383+0.000168
#
# [1]	train-rmse:0.250150+0.000001	test-rmse:0.250150+0.000007
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125150+0.000000	test-rmse:0.125150+0.000008
# [3]	train-rmse:0.062613+0.000000	test-rmse:0.062613+0.000009
# [4]	train-rmse:0.031326+0.000000	test-rmse:0.031326+0.000009
# [5]	train-rmse:0.015674+0.000000	test-rmse:0.015674+0.000009
# [6]	train-rmse:0.007844+0.000000	test-rmse:0.007845+0.000010
# [7]	train-rmse:0.003930+0.000001	test-rmse:0.003930+0.000010
# [8]	train-rmse:0.001977+0.000001	test-rmse:0.001977+0.000011
# [9]	train-rmse:0.001011+0.000003	test-rmse:0.001011+0.000013
# [10]	train-rmse:0.000548+0.000005	test-rmse:0.000548+0.000017
# [11]	train-rmse:0.000345+0.000009	test-rmse:0.000345+0.000022
# [12]	train-rmse:0.000272+0.000011	test-rmse:0.000272+0.000025
# [13]	train-rmse:0.000250+0.000013	test-rmse:0.000250+0.000025
# [14]	train-rmse:0.000244+0.000013	test-rmse:0.000244+0.000025
# [15]	train-rmse:0.000242+0.000013	test-rmse:0.000242+0.000025
# [16]	train-rmse:0.000242+0.000013	test-rmse:0.000242+0.000025
# [17]	train-rmse:0.000242+0.000013	test-rmse:0.000242+0.000025
# [18]	train-rmse:0.000242+0.000013	test-rmse:0.000242+0.000025
# [19]	train-rmse:0.000242+0.000013	test-rmse:0.000242+0.000025
# Stopping. Best iteration:
# [16]	train-rmse:0.000242+0.000013	test-rmse:0.000242+0.000025
#
# [1]	train-rmse:0.250155+0.000013	test-rmse:0.250155+0.000065
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125160+0.000007	test-rmse:0.125160+0.000072
# [3]	train-rmse:0.062632+0.000003	test-rmse:0.062632+0.000075
# [4]	train-rmse:0.031364+0.000003	test-rmse:0.031363+0.000076
# [5]	train-rmse:0.015749+0.000005	test-rmse:0.015749+0.000076
# [6]	train-rmse:0.007994+0.000010	test-rmse:0.007994+0.000075
# [7]	train-rmse:0.004220+0.000020	test-rmse:0.004221+0.000074
# [8]	train-rmse:0.002503+0.000032	test-rmse:0.002506+0.000079
# [9]	train-rmse:0.001826+0.000047	test-rmse:0.001844+0.000096
# [10]	train-rmse:0.001607+0.000050	test-rmse:0.001636+0.000105
# [11]	train-rmse:0.001541+0.000052	test-rmse:0.001588+0.000114
# [12]	train-rmse:0.001523+0.000051	test-rmse:0.001573+0.000115
# [13]	train-rmse:0.001515+0.000052	test-rmse:0.001572+0.000117
# [14]	train-rmse:0.001506+0.000056	test-rmse:0.001571+0.000116
# [15]	train-rmse:0.001498+0.000054	test-rmse:0.001574+0.000115
# [16]	train-rmse:0.001492+0.000057	test-rmse:0.001577+0.000119
# [17]	train-rmse:0.001485+0.000055	test-rmse:0.001585+0.000120
# Stopping. Best iteration:
# [14]	train-rmse:0.001506+0.000056	test-rmse:0.001571+0.000116
#
# [1]	train-rmse:0.251319+0.000134	test-rmse:0.251319+0.000687
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.127471+0.000146	test-rmse:0.127470+0.000724
# [3]	train-rmse:0.067121+0.000282	test-rmse:0.067158+0.000753
# [4]	train-rmse:0.039411+0.000437	test-rmse:0.039538+0.000930
# [5]	train-rmse:0.028413+0.000569	test-rmse:0.028723+0.001201
# [6]	train-rmse:0.024798+0.000604	test-rmse:0.025246+0.001449
# [7]	train-rmse:0.023743+0.000616	test-rmse:0.024262+0.001562
# [8]	train-rmse:0.023335+0.000600	test-rmse:0.024023+0.001632
# [9]	train-rmse:0.023135+0.000476	test-rmse:0.023992+0.001599
# [10]	train-rmse:0.022946+0.000582	test-rmse:0.023996+0.001609
# [11]	train-rmse:0.022861+0.000568	test-rmse:0.024004+0.001619
# [12]	train-rmse:0.022770+0.000569	test-rmse:0.023988+0.001654
# [13]	train-rmse:0.022693+0.000567	test-rmse:0.024010+0.001664
# [14]	train-rmse:0.022601+0.000528	test-rmse:0.024050+0.001643
# [15]	train-rmse:0.022569+0.000533	test-rmse:0.024066+0.001653
# Stopping. Best iteration:
# [12]	train-rmse:0.022770+0.000569	test-rmse:0.023988+0.001654
#
# [1]	train-rmse:0.250616+0.000049	test-rmse:0.250616+0.000284
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.126078+0.000021	test-rmse:0.126079+0.000289
# [3]	train-rmse:0.064449+0.000055	test-rmse:0.064448+0.000255
# [4]	train-rmse:0.034788+0.000119	test-rmse:0.034798+0.000243
# [5]	train-rmse:0.021690+0.000205	test-rmse:0.021748+0.000308
# [6]	train-rmse:0.016836+0.000266	test-rmse:0.016955+0.000457
# [7]	train-rmse:0.015349+0.000294	test-rmse:0.015554+0.000541
# [8]	train-rmse:0.014921+0.000298	test-rmse:0.015174+0.000583
# [9]	train-rmse:0.014766+0.000282	test-rmse:0.015072+0.000606
# [10]	train-rmse:0.014707+0.000279	test-rmse:0.015047+0.000611
# [11]	train-rmse:0.014670+0.000274	test-rmse:0.015032+0.000605
# [12]	train-rmse:0.014641+0.000292	test-rmse:0.015041+0.000617
# [13]	train-rmse:0.014603+0.000297	test-rmse:0.015047+0.000615
# [14]	train-rmse:0.014582+0.000293	test-rmse:0.015062+0.000612
# Stopping. Best iteration:
# [11]	train-rmse:0.014670+0.000274	test-rmse:0.015032+0.000605
#
# [1]	train-rmse:0.251129+0.000147	test-rmse:0.251129+0.000982
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.127097+0.000097	test-rmse:0.127097+0.000916
# [3]	train-rmse:0.066418+0.000319	test-rmse:0.066424+0.000647
# [4]	train-rmse:0.038252+0.000629	test-rmse:0.038366+0.000498
# [5]	train-rmse:0.026823+0.000887	test-rmse:0.027180+0.001110
# [6]	train-rmse:0.022821+0.001079	test-rmse:0.023586+0.001705
# [7]	train-rmse:0.021507+0.001038	test-rmse:0.022722+0.002019
# [8]	train-rmse:0.021014+0.000839	test-rmse:0.022428+0.002190
# [9]	train-rmse:0.020907+0.000829	test-rmse:0.022411+0.002251
# [10]	train-rmse:0.020757+0.000721	test-rmse:0.022397+0.002312
# [11]	train-rmse:0.020678+0.000736	test-rmse:0.022420+0.002331
# [12]	train-rmse:0.020580+0.000740	test-rmse:0.022552+0.002375
# [13]	train-rmse:0.020543+0.000723	test-rmse:0.022562+0.002361
# Stopping. Best iteration:
# [10]	train-rmse:0.020757+0.000721	test-rmse:0.022397+0.002312
#
# [1]	train-rmse:0.251389+0.000138	test-rmse:0.251389+0.000550
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.127609+0.000137	test-rmse:0.127608+0.000677
# [3]	train-rmse:0.067394+0.000199	test-rmse:0.067390+0.000834
# [4]	train-rmse:0.039955+0.000282	test-rmse:0.040019+0.000960
# [5]	train-rmse:0.029208+0.000361	test-rmse:0.029368+0.001043
# [6]	train-rmse:0.025758+0.000397	test-rmse:0.026041+0.001049
# [7]	train-rmse:0.024773+0.000419	test-rmse:0.025144+0.001026
# [8]	train-rmse:0.024488+0.000419	test-rmse:0.024916+0.001003
# [9]	train-rmse:0.024365+0.000433	test-rmse:0.024867+0.000981
# [10]	train-rmse:0.024283+0.000437	test-rmse:0.024889+0.000967
# [11]	train-rmse:0.024228+0.000419	test-rmse:0.024934+0.000956
# [12]	train-rmse:0.024174+0.000418	test-rmse:0.024939+0.000950
# Stopping. Best iteration:
# [9]	train-rmse:0.024365+0.000433	test-rmse:0.024867+0.000981
#
# [1]	train-rmse:0.251612+0.000111	test-rmse:0.251612+0.000424
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.127967+0.000113	test-rmse:0.128016+0.000427
# [3]	train-rmse:0.067903+0.000160	test-rmse:0.067983+0.000499
# [4]	train-rmse:0.040636+0.000225	test-rmse:0.040748+0.000669
# [5]	train-rmse:0.030082+0.000285	test-rmse:0.030294+0.000821
# [6]	train-rmse:0.026689+0.000312	test-rmse:0.027050+0.000872
# [7]	train-rmse:0.025684+0.000363	test-rmse:0.026220+0.000842
# [8]	train-rmse:0.025371+0.000373	test-rmse:0.026007+0.000767
# [9]	train-rmse:0.025242+0.000354	test-rmse:0.025986+0.000766
# [10]	train-rmse:0.025137+0.000362	test-rmse:0.026062+0.000844
# [11]	train-rmse:0.025101+0.000356	test-rmse:0.026061+0.000818
# [12]	train-rmse:0.025023+0.000336	test-rmse:0.026054+0.000826
# Stopping. Best iteration:
# [9]	train-rmse:0.025242+0.000354	test-rmse:0.025986+0.000766
#
# [1]	train-rmse:0.250194+0.000054	test-rmse:0.250194+0.000252
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125238+0.000037	test-rmse:0.125238+0.000288
# [3]	train-rmse:0.062788+0.000040	test-rmse:0.062788+0.000323
# [4]	train-rmse:0.031674+0.000064	test-rmse:0.031673+0.000376
# [5]	train-rmse:0.016357+0.000115	test-rmse:0.016359+0.000463
# [6]	train-rmse:0.009127+0.000204	test-rmse:0.009124+0.000596
# [7]	train-rmse:0.006073+0.000300	test-rmse:0.006091+0.000717
# [8]	train-rmse:0.005012+0.000367	test-rmse:0.005045+0.000777
# [9]	train-rmse:0.004686+0.000394	test-rmse:0.004754+0.000777
# [10]	train-rmse:0.004592+0.000402	test-rmse:0.004683+0.000777
# [11]	train-rmse:0.004546+0.000401	test-rmse:0.004673+0.000772
# [12]	train-rmse:0.004455+0.000335	test-rmse:0.004691+0.000750
# [13]	train-rmse:0.004439+0.000339	test-rmse:0.004699+0.000744
# [14]	train-rmse:0.004428+0.000335	test-rmse:0.004696+0.000744
# Stopping. Best iteration:
# [11]	train-rmse:0.004546+0.000401	test-rmse:0.004673+0.000772
#
# [1]	train-rmse:0.250156+0.000010	test-rmse:0.250156+0.000053
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125162+0.000005	test-rmse:0.125162+0.000058
# [3]	train-rmse:0.062636+0.000002	test-rmse:0.062636+0.000060
# [4]	train-rmse:0.031373+0.000002	test-rmse:0.031373+0.000060
# [5]	train-rmse:0.015767+0.000005	test-rmse:0.015767+0.000057
# [6]	train-rmse:0.008030+0.000011	test-rmse:0.008030+0.000052
# [7]	train-rmse:0.004283+0.000022	test-rmse:0.004287+0.000048
# [8]	train-rmse:0.002606+0.000037	test-rmse:0.002617+0.000055
# [9]	train-rmse:0.001957+0.000044	test-rmse:0.001994+0.000074
# [10]	train-rmse:0.001756+0.000048	test-rmse:0.001807+0.000085
# [11]	train-rmse:0.001689+0.000048	test-rmse:0.001759+0.000090
# [12]	train-rmse:0.001666+0.000049	test-rmse:0.001751+0.000094
# [13]	train-rmse:0.001646+0.000035	test-rmse:0.001750+0.000094
# [14]	train-rmse:0.001639+0.000033	test-rmse:0.001750+0.000095
# [15]	train-rmse:0.001632+0.000031	test-rmse:0.001751+0.000095
# [16]	train-rmse:0.001627+0.000034	test-rmse:0.001755+0.000099
# [17]	train-rmse:0.001600+0.000024	test-rmse:0.001758+0.000097
# Stopping. Best iteration:
# [14]	train-rmse:0.001639+0.000033	test-rmse:0.001750+0.000095
#
# [1]	train-rmse:0.256118+0.000204	test-rmse:0.256117+0.001196
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.136412+0.000090	test-rmse:0.136598+0.001092
# [3]	train-rmse:0.082442+0.000065	test-rmse:0.082949+0.001009
# [4]	train-rmse:0.061678+0.000065	test-rmse:0.062405+0.000636
# [5]	train-rmse:0.055057+0.000128	test-rmse:0.056167+0.000316
# [6]	train-rmse:0.053148+0.000171	test-rmse:0.054451+0.000198
# [7]	train-rmse:0.052524+0.000183	test-rmse:0.053891+0.000148
# [8]	train-rmse:0.052237+0.000213	test-rmse:0.053706+0.000199
# [9]	train-rmse:0.052062+0.000205	test-rmse:0.053690+0.000238
# [10]	train-rmse:0.051851+0.000280	test-rmse:0.053684+0.000259
# [11]	train-rmse:0.051706+0.000273	test-rmse:0.053824+0.000294
# [12]	train-rmse:0.051545+0.000213	test-rmse:0.053870+0.000240
# [13]	train-rmse:0.051432+0.000217	test-rmse:0.053817+0.000303
# Stopping. Best iteration:
# [10]	train-rmse:0.051851+0.000280	test-rmse:0.053684+0.000259
#
# [1]	train-rmse:0.250945+0.000086	test-rmse:0.250945+0.000447
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.126731+0.000036	test-rmse:0.126731+0.000478
# [3]	train-rmse:0.065707+0.000001	test-rmse:0.065701+0.000466
# [4]	train-rmse:0.036999+0.000018	test-rmse:0.037072+0.000441
# [5]	train-rmse:0.025029+0.000047	test-rmse:0.025176+0.000332
# [6]	train-rmse:0.020925+0.000055	test-rmse:0.021143+0.000185
# [7]	train-rmse:0.019708+0.000072	test-rmse:0.020020+0.000061
# [8]	train-rmse:0.019341+0.000081	test-rmse:0.019726+0.000129
# [9]	train-rmse:0.019227+0.000090	test-rmse:0.019639+0.000168
# [10]	train-rmse:0.019156+0.000100	test-rmse:0.019620+0.000187
# [11]	train-rmse:0.019095+0.000082	test-rmse:0.019605+0.000191
# [12]	train-rmse:0.019024+0.000072	test-rmse:0.019594+0.000178
# [13]	train-rmse:0.018993+0.000079	test-rmse:0.019609+0.000172
# [14]	train-rmse:0.018960+0.000083	test-rmse:0.019602+0.000168
# [15]	train-rmse:0.018898+0.000087	test-rmse:0.019593+0.000157
# [16]	train-rmse:0.018845+0.000091	test-rmse:0.019612+0.000187
# [17]	train-rmse:0.018771+0.000056	test-rmse:0.019624+0.000175
# [18]	train-rmse:0.018713+0.000040	test-rmse:0.019621+0.000169
# Stopping. Best iteration:
# [15]	train-rmse:0.018898+0.000087	test-rmse:0.019593+0.000157
#
# [1]	train-rmse:0.271163+0.000543	test-rmse:0.271452+0.002986
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.162315+0.000589	test-rmse:0.162918+0.002780
# [3]	train-rmse:0.120130+0.000743	test-rmse:0.121431+0.001973
# [4]	train-rmse:0.106659+0.000823	test-rmse:0.108110+0.001325
# [5]	train-rmse:0.102719+0.000933	test-rmse:0.104740+0.001347
# [6]	train-rmse:0.101450+0.000973	test-rmse:0.103869+0.001333
# [7]	train-rmse:0.100960+0.001006	test-rmse:0.103608+0.001414
# [8]	train-rmse:0.100545+0.000823	test-rmse:0.103550+0.001587
# [9]	train-rmse:0.100214+0.000736	test-rmse:0.103464+0.001628
# [10]	train-rmse:0.099762+0.000813	test-rmse:0.103301+0.001525
# [11]	train-rmse:0.099411+0.000869	test-rmse:0.103275+0.001531
# [12]	train-rmse:0.099180+0.000942	test-rmse:0.103180+0.001564
# [13]	train-rmse:0.098868+0.000974	test-rmse:0.103159+0.001605
# [14]	train-rmse:0.098584+0.000923	test-rmse:0.103293+0.001606
# [15]	train-rmse:0.098342+0.000876	test-rmse:0.103290+0.001507
# [16]	train-rmse:0.098218+0.000871	test-rmse:0.103189+0.001493
# Stopping. Best iteration:
# [13]	train-rmse:0.098868+0.000974	test-rmse:0.103159+0.001605
#
# [1]	train-rmse:0.287828+0.000174	test-rmse:0.288285+0.002135
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.187536+0.000748	test-rmse:0.189343+0.001515
# [3]	train-rmse:0.151763+0.001065	test-rmse:0.154306+0.000693
# [4]	train-rmse:0.141045+0.001106	test-rmse:0.144198+0.000689
# [5]	train-rmse:0.137862+0.001005	test-rmse:0.141487+0.000964
# [6]	train-rmse:0.136661+0.001065	test-rmse:0.140717+0.001453
# [7]	train-rmse:0.135921+0.001247	test-rmse:0.140667+0.001616
# [8]	train-rmse:0.135390+0.001253	test-rmse:0.140768+0.001703
# [9]	train-rmse:0.134916+0.001218	test-rmse:0.140707+0.001866
# [10]	train-rmse:0.134689+0.001166	test-rmse:0.140788+0.001873
# Stopping. Best iteration:
# [7]	train-rmse:0.135921+0.001247	test-rmse:0.140667+0.001616
#
# [1]	train-rmse:0.256279+0.000267	test-rmse:0.256278+0.001281
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.136724+0.000215	test-rmse:0.136893+0.001461
# [3]	train-rmse:0.082932+0.000341	test-rmse:0.083283+0.001389
# [4]	train-rmse:0.062340+0.000461	test-rmse:0.062911+0.000956
# [5]	train-rmse:0.055899+0.000504	test-rmse:0.056651+0.000961
# [6]	train-rmse:0.054024+0.000543	test-rmse:0.054979+0.001010
# [7]	train-rmse:0.053412+0.000596	test-rmse:0.054497+0.001005
# [8]	train-rmse:0.053088+0.000628	test-rmse:0.054323+0.000968
# [9]	train-rmse:0.052856+0.000714	test-rmse:0.054348+0.001002
# [10]	train-rmse:0.052761+0.000738	test-rmse:0.054304+0.000948
# [11]	train-rmse:0.052563+0.000670	test-rmse:0.054311+0.000911
# [12]	train-rmse:0.052425+0.000652	test-rmse:0.054342+0.000899
# [13]	train-rmse:0.052277+0.000600	test-rmse:0.054362+0.000887
# Stopping. Best iteration:
# [10]	train-rmse:0.052761+0.000738	test-rmse:0.054304+0.000948
#
# [1]	train-rmse:0.251780+0.000236	test-rmse:0.251779+0.001089
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.128359+0.000164	test-rmse:0.128472+0.001255
# [3]	train-rmse:0.068629+0.000152	test-rmse:0.068735+0.001439
# [4]	train-rmse:0.041863+0.000184	test-rmse:0.041999+0.001447
# [5]	train-rmse:0.031698+0.000217	test-rmse:0.032003+0.001172
# [6]	train-rmse:0.028532+0.000226	test-rmse:0.028976+0.000884
# [7]	train-rmse:0.027617+0.000241	test-rmse:0.028123+0.000653
# [8]	train-rmse:0.027303+0.000248	test-rmse:0.027857+0.000614
# [9]	train-rmse:0.027189+0.000257	test-rmse:0.027806+0.000560
# [10]	train-rmse:0.027060+0.000232	test-rmse:0.027815+0.000555
# [11]	train-rmse:0.026987+0.000245	test-rmse:0.027819+0.000526
# [12]	train-rmse:0.026895+0.000265	test-rmse:0.027836+0.000503
# Stopping. Best iteration:
# [9]	train-rmse:0.027189+0.000257	test-rmse:0.027806+0.000560
#
# [1]	train-rmse:0.250635+0.000067	test-rmse:0.250635+0.000345
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.126117+0.000030	test-rmse:0.126116+0.000371
# [3]	train-rmse:0.064523+0.000012	test-rmse:0.064523+0.000369
# [4]	train-rmse:0.034913+0.000019	test-rmse:0.034974+0.000347
# [5]	train-rmse:0.021884+0.000038	test-rmse:0.021986+0.000288
# [6]	train-rmse:0.017066+0.000049	test-rmse:0.017242+0.000180
# [7]	train-rmse:0.015584+0.000052	test-rmse:0.015806+0.000088
# [8]	train-rmse:0.015142+0.000049	test-rmse:0.015409+0.000074
# [9]	train-rmse:0.015007+0.000055	test-rmse:0.015298+0.000098
# [10]	train-rmse:0.014940+0.000057	test-rmse:0.015293+0.000106
# [11]	train-rmse:0.014891+0.000048	test-rmse:0.015271+0.000110
# [12]	train-rmse:0.014848+0.000066	test-rmse:0.015268+0.000103
# [13]	train-rmse:0.014823+0.000073	test-rmse:0.015250+0.000095
# [14]	train-rmse:0.014794+0.000095	test-rmse:0.015252+0.000106
# [15]	train-rmse:0.014757+0.000097	test-rmse:0.015255+0.000118
# [16]	train-rmse:0.014720+0.000089	test-rmse:0.015256+0.000119
# Stopping. Best iteration:
# [13]	train-rmse:0.014823+0.000073	test-rmse:0.015250+0.000095
#
# [1]	train-rmse:0.250150+0.000000	test-rmse:0.250150+0.000001
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125150+0.000000	test-rmse:0.125150+0.000001
# [3]	train-rmse:0.062612+0.000000	test-rmse:0.062612+0.000001
# [4]	train-rmse:0.031325+0.000000	test-rmse:0.031325+0.000002
# [5]	train-rmse:0.015672+0.000000	test-rmse:0.015672+0.000002
# [6]	train-rmse:0.007841+0.000000	test-rmse:0.007841+0.000002
# [7]	train-rmse:0.003923+0.000000	test-rmse:0.003923+0.000001
# [8]	train-rmse:0.001964+0.000000	test-rmse:0.001964+0.000001
# [9]	train-rmse:0.000984+0.000000	test-rmse:0.000984+0.000001
# [10]	train-rmse:0.000496+0.000000	test-rmse:0.000496+0.000001
# [11]	train-rmse:0.000255+0.000001	test-rmse:0.000255+0.000002
# [12]	train-rmse:0.000140+0.000002	test-rmse:0.000140+0.000003
# [13]	train-rmse:0.000091+0.000002	test-rmse:0.000092+0.000004
# [14]	train-rmse:0.000074+0.000003	test-rmse:0.000074+0.000006
# [15]	train-rmse:0.000069+0.000003	test-rmse:0.000069+0.000006
# [16]	train-rmse:0.000068+0.000003	test-rmse:0.000068+0.000006
# [17]	train-rmse:0.000068+0.000003	test-rmse:0.000068+0.000006
# [18]	train-rmse:0.000068+0.000003	test-rmse:0.000068+0.000006
# [19]	train-rmse:0.000068+0.000003	test-rmse:0.000068+0.000006
# Stopping. Best iteration:
# [16]	train-rmse:0.000068+0.000003	test-rmse:0.000068+0.000006
#
# [1]	train-rmse:0.250150+0.000000	test-rmse:0.250150+0.000000
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125150+0.000000	test-rmse:0.125150+0.000001
# [3]	train-rmse:0.062612+0.000000	test-rmse:0.062612+0.000000
# [4]	train-rmse:0.031325+0.000000	test-rmse:0.031325+0.000001
# [5]	train-rmse:0.015672+0.000000	test-rmse:0.015672+0.000001
# [6]	train-rmse:0.007841+0.000000	test-rmse:0.007841+0.000000
# [7]	train-rmse:0.003923+0.000000	test-rmse:0.003923+0.000001
# [8]	train-rmse:0.001963+0.000000	test-rmse:0.001963+0.000000
# [9]	train-rmse:0.000982+0.000000	test-rmse:0.000982+0.000001
# [10]	train-rmse:0.000492+0.000000	test-rmse:0.000492+0.000000
# [11]	train-rmse:0.000247+0.000000	test-rmse:0.000247+0.000000
# [12]	train-rmse:0.000124+0.000000	test-rmse:0.000125+0.000000
# [13]	train-rmse:0.000064+0.000000	test-rmse:0.000065+0.000000
# [14]	train-rmse:0.000036+0.000000	test-rmse:0.000036+0.000001
# [15]	train-rmse:0.000025+0.000000	test-rmse:0.000025+0.000001
# [16]	train-rmse:0.000021+0.000000	test-rmse:0.000020+0.000001
# [17]	train-rmse:0.000019+0.000001	test-rmse:0.000019+0.000001
# [18]	train-rmse:0.000019+0.000001	test-rmse:0.000019+0.000002
# [19]	train-rmse:0.000019+0.000001	test-rmse:0.000019+0.000002
# [20]	train-rmse:0.000019+0.000001	test-rmse:0.000019+0.000002
# [21]	train-rmse:0.000019+0.000001	test-rmse:0.000019+0.000002
# Stopping. Best iteration:
# [18]	train-rmse:0.000019+0.000001	test-rmse:0.000019+0.000002
#
# [1]	train-rmse:0.250150+0.000003	test-rmse:0.250150+0.000015
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125150+0.000002	test-rmse:0.125150+0.000017
# [3]	train-rmse:0.062614+0.000000	test-rmse:0.062614+0.000018
# [4]	train-rmse:0.031327+0.000000	test-rmse:0.031327+0.000018
# [5]	train-rmse:0.015677+0.000000	test-rmse:0.015677+0.000018
# [6]	train-rmse:0.007850+0.000000	test-rmse:0.007850+0.000018
# [7]	train-rmse:0.003941+0.000001	test-rmse:0.003941+0.000016
# [8]	train-rmse:0.001999+0.000002	test-rmse:0.001999+0.000014
# [9]	train-rmse:0.001053+0.000004	test-rmse:0.001053+0.000011
# [10]	train-rmse:0.000621+0.000007	test-rmse:0.000622+0.000006
# [11]	train-rmse:0.000453+0.000009	test-rmse:0.000453+0.000011
# [12]	train-rmse:0.000400+0.000011	test-rmse:0.000400+0.000017
# [13]	train-rmse:0.000385+0.000011	test-rmse:0.000386+0.000020
# [14]	train-rmse:0.000382+0.000011	test-rmse:0.000381+0.000021
# [15]	train-rmse:0.000381+0.000011	test-rmse:0.000381+0.000022
# [16]	train-rmse:0.000380+0.000011	test-rmse:0.000380+0.000023
# [17]	train-rmse:0.000380+0.000011	test-rmse:0.000380+0.000023
# [18]	train-rmse:0.000380+0.000011	test-rmse:0.000380+0.000023
# [19]	train-rmse:0.000380+0.000011	test-rmse:0.000380+0.000023
# Stopping. Best iteration:
# [16]	train-rmse:0.000380+0.000011	test-rmse:0.000380+0.000023
#
# [1]	train-rmse:0.250150+0.000000	test-rmse:0.250150+0.000002
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125150+0.000000	test-rmse:0.125150+0.000003
# [3]	train-rmse:0.062613+0.000000	test-rmse:0.062613+0.000003
# [4]	train-rmse:0.031326+0.000000	test-rmse:0.031326+0.000003
# [5]	train-rmse:0.015674+0.000000	test-rmse:0.015674+0.000003
# [6]	train-rmse:0.007846+0.000000	test-rmse:0.007846+0.000003
# [7]	train-rmse:0.003933+0.000001	test-rmse:0.003933+0.000003
# [8]	train-rmse:0.001983+0.000002	test-rmse:0.001983+0.000005
# [9]	train-rmse:0.001022+0.000004	test-rmse:0.001022+0.000008
# [10]	train-rmse:0.000568+0.000006	test-rmse:0.000568+0.000013
# [11]	train-rmse:0.000376+0.000010	test-rmse:0.000375+0.000020
# [12]	train-rmse:0.000310+0.000012	test-rmse:0.000309+0.000024
# [13]	train-rmse:0.000291+0.000013	test-rmse:0.000290+0.000025
# [14]	train-rmse:0.000286+0.000013	test-rmse:0.000285+0.000025
# [15]	train-rmse:0.000285+0.000013	test-rmse:0.000284+0.000025
# [16]	train-rmse:0.000284+0.000013	test-rmse:0.000283+0.000026
# [17]	train-rmse:0.000284+0.000013	test-rmse:0.000283+0.000026
# [18]	train-rmse:0.000284+0.000013	test-rmse:0.000283+0.000026
# [19]	train-rmse:0.000284+0.000013	test-rmse:0.000283+0.000026
# Stopping. Best iteration:
# [16]	train-rmse:0.000284+0.000013	test-rmse:0.000283+0.000026
#
# [1]	train-rmse:0.250151+0.000004	test-rmse:0.250151+0.000020
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125152+0.000002	test-rmse:0.125152+0.000021
# [3]	train-rmse:0.062616+0.000001	test-rmse:0.062617+0.000022
# [4]	train-rmse:0.031333+0.000000	test-rmse:0.031332+0.000023
# [5]	train-rmse:0.015687+0.000001	test-rmse:0.015687+0.000022
# [6]	train-rmse:0.007871+0.000002	test-rmse:0.007871+0.000022
# [7]	train-rmse:0.003984+0.000003	test-rmse:0.003984+0.000021
# [8]	train-rmse:0.002083+0.000006	test-rmse:0.002083+0.000020
# [9]	train-rmse:0.001204+0.000011	test-rmse:0.001204+0.000021
# [10]	train-rmse:0.000851+0.000015	test-rmse:0.000854+0.000026
# [11]	train-rmse:0.000734+0.000017	test-rmse:0.000739+0.000030
# [12]	train-rmse:0.000702+0.000018	test-rmse:0.000708+0.000033
# [13]	train-rmse:0.000692+0.000018	test-rmse:0.000700+0.000034
# [14]	train-rmse:0.000690+0.000018	test-rmse:0.000698+0.000035
# [15]	train-rmse:0.000690+0.000018	test-rmse:0.000697+0.000035
# [16]	train-rmse:0.000690+0.000018	test-rmse:0.000697+0.000035
# ...
# [6]	train-rmse:0.041471+0.000485	test-rmse:0.042408+0.001002
# [7]	train-rmse:0.040750+0.000518	test-rmse:0.041896+0.000981
# [8]	train-rmse:0.040431+0.000472	test-rmse:0.041744+0.000953
# [9]	train-rmse:0.040238+0.000491	test-rmse:0.041719+0.000949
# [10]	train-rmse:0.040068+0.000486	test-rmse:0.041724+0.001009
# [11]	train-rmse:0.039898+0.000515	test-rmse:0.041814+0.001112
# [12]	train-rmse:0.039759+0.000541	test-rmse:0.041795+0.001104
# Stopping. Best iteration:
# [9]	train-rmse:0.040238+0.000491	test-rmse:0.041719+0.000949
#
# [1]	train-rmse:0.250350+0.000070	test-rmse:0.250350+0.000356
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125549+0.000033	test-rmse:0.125549+0.000388
# [3]	train-rmse:0.063394+0.000022	test-rmse:0.063382+0.000377
# [4]	train-rmse:0.032777+0.000017	test-rmse:0.032781+0.000326
# [5]	train-rmse:0.018310+0.000022	test-rmse:0.018351+0.000290
# [6]	train-rmse:0.012212+0.000039	test-rmse:0.012299+0.000209
# [7]	train-rmse:0.010087+0.000050	test-rmse:0.010223+0.000139
# [8]	train-rmse:0.009436+0.000037	test-rmse:0.009621+0.000103
# [9]	train-rmse:0.009245+0.000038	test-rmse:0.009463+0.000099
# [10]	train-rmse:0.009181+0.000025	test-rmse:0.009420+0.000109
# [11]	train-rmse:0.009142+0.000015	test-rmse:0.009408+0.000104
# [12]	train-rmse:0.009119+0.000026	test-rmse:0.009398+0.000103
# [13]	train-rmse:0.009096+0.000025	test-rmse:0.009388+0.000101
# [14]	train-rmse:0.009075+0.000029	test-rmse:0.009384+0.000096
# [15]	train-rmse:0.009059+0.000026	test-rmse:0.009381+0.000098
# [16]	train-rmse:0.009032+0.000023	test-rmse:0.009376+0.000086
# [17]	train-rmse:0.009011+0.000032	test-rmse:0.009380+0.000080
# [18]	train-rmse:0.008969+0.000040	test-rmse:0.009379+0.000077
# [19]	train-rmse:0.008944+0.000050	test-rmse:0.009377+0.000082
# Stopping. Best iteration:
# [16]	train-rmse:0.009032+0.000023	test-rmse:0.009376+0.000086
#
# [1]	train-rmse:0.251131+0.000052	test-rmse:0.251130+0.000253
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.127007+0.000030	test-rmse:0.127011+0.000219
# [3]	train-rmse:0.066053+0.000045	test-rmse:0.066092+0.000161
# [4]	train-rmse:0.037492+0.000059	test-rmse:0.037582+0.000184
# [5]	train-rmse:0.025646+0.000100	test-rmse:0.025849+0.000161
# [6]	train-rmse:0.021608+0.000114	test-rmse:0.021900+0.000205
# [7]	train-rmse:0.020415+0.000137	test-rmse:0.020778+0.000262
# [8]	train-rmse:0.020021+0.000120	test-rmse:0.020425+0.000337
# [9]	train-rmse:0.019870+0.000125	test-rmse:0.020332+0.000316
# [10]	train-rmse:0.019803+0.000117	test-rmse:0.020290+0.000309
# [11]	train-rmse:0.019704+0.000114	test-rmse:0.020231+0.000297
# [12]	train-rmse:0.019631+0.000104	test-rmse:0.020206+0.000290
# [13]	train-rmse:0.019580+0.000099	test-rmse:0.020207+0.000311
# [14]	train-rmse:0.019523+0.000132	test-rmse:0.020209+0.000344
# [15]	train-rmse:0.019497+0.000124	test-rmse:0.020212+0.000331
# Stopping. Best iteration:
# [12]	train-rmse:0.019631+0.000104	test-rmse:0.020206+0.000290
#
# [1]	train-rmse:0.266039+0.000217	test-rmse:0.266451+0.002030
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.152129+0.000632	test-rmse:0.152968+0.001886
# [3]	train-rmse:0.105168+0.001048	test-rmse:0.106468+0.001571
# [4]	train-rmse:0.089114+0.001201	test-rmse:0.091065+0.001414
# [5]	train-rmse:0.084255+0.001263	test-rmse:0.086598+0.001581
# [6]	train-rmse:0.082608+0.001163	test-rmse:0.085238+0.001665
# [7]	train-rmse:0.082057+0.001189	test-rmse:0.084724+0.001723
# [8]	train-rmse:0.081688+0.001111	test-rmse:0.084577+0.001742
# [9]	train-rmse:0.081415+0.001120	test-rmse:0.084553+0.001752
# [10]	train-rmse:0.081065+0.001247	test-rmse:0.084634+0.001605
# [11]	train-rmse:0.080716+0.001402	test-rmse:0.084678+0.001561
# [12]	train-rmse:0.080382+0.001427	test-rmse:0.084624+0.001524
# Stopping. Best iteration:
# [9]	train-rmse:0.081415+0.001120	test-rmse:0.084553+0.001752
#
# [1]	train-rmse:0.264728+0.000749	test-rmse:0.265171+0.004149
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.150424+0.000441	test-rmse:0.151314+0.003821
# [3]	train-rmse:0.102764+0.000552	test-rmse:0.104441+0.003115
# [4]	train-rmse:0.086472+0.000670	test-rmse:0.088710+0.001818
# [5]	train-rmse:0.081531+0.000635	test-rmse:0.083987+0.000995
# [6]	train-rmse:0.079977+0.000818	test-rmse:0.082723+0.000673
# [7]	train-rmse:0.079478+0.000873	test-rmse:0.082442+0.000799
# [8]	train-rmse:0.079076+0.000817	test-rmse:0.082177+0.001120
# [9]	train-rmse:0.078849+0.000736	test-rmse:0.082242+0.001112
# [10]	train-rmse:0.078654+0.000791	test-rmse:0.082173+0.001027
# [11]	train-rmse:0.078512+0.000865	test-rmse:0.082227+0.001084
# [12]	train-rmse:0.078240+0.000856	test-rmse:0.082047+0.001238
# [13]	train-rmse:0.078027+0.000783	test-rmse:0.081937+0.001304
# [14]	train-rmse:0.077825+0.000763	test-rmse:0.082078+0.001316
# [15]	train-rmse:0.077634+0.000688	test-rmse:0.081890+0.001431
# [16]	train-rmse:0.077335+0.000684	test-rmse:0.082065+0.001399
# [17]	train-rmse:0.077080+0.000544	test-rmse:0.081963+0.001497
# [18]	train-rmse:0.076921+0.000565	test-rmse:0.081938+0.001395
# Stopping. Best iteration:
# [15]	train-rmse:0.077634+0.000688	test-rmse:0.081890+0.001431
#
# [1]	train-rmse:0.261843+0.000594	test-rmse:0.262175+0.002129
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.146072+0.000844	test-rmse:0.146755+0.002419
# [3]	train-rmse:0.097063+0.001147	test-rmse:0.098287+0.002693
# [4]	train-rmse:0.079901+0.001315	test-rmse:0.081463+0.002403
# [5]	train-rmse:0.074771+0.001435	test-rmse:0.076656+0.002311
# [6]	train-rmse:0.073152+0.001472	test-rmse:0.075394+0.002345
# [7]	train-rmse:0.072461+0.001615	test-rmse:0.074878+0.002479
# [8]	train-rmse:0.072167+0.001595	test-rmse:0.074825+0.002350
# [9]	train-rmse:0.071909+0.001505	test-rmse:0.074731+0.002396
# [10]	train-rmse:0.071579+0.001513	test-rmse:0.074674+0.002429
# [11]	train-rmse:0.071465+0.001497	test-rmse:0.074649+0.002373
# [12]	train-rmse:0.071233+0.001453	test-rmse:0.074673+0.002331
# [13]	train-rmse:0.071048+0.001567	test-rmse:0.074710+0.002297
# [14]	train-rmse:0.070659+0.001430	test-rmse:0.074626+0.002390
# [15]	train-rmse:0.070526+0.001450	test-rmse:0.074607+0.002407
# [16]	train-rmse:0.070393+0.001432	test-rmse:0.074498+0.002486
# [17]	train-rmse:0.070110+0.001378	test-rmse:0.074540+0.002559
# [18]	train-rmse:0.070006+0.001358	test-rmse:0.074534+0.002579
# [19]	train-rmse:0.069836+0.001405	test-rmse:0.074537+0.002676
# Stopping. Best iteration:
# [16]	train-rmse:0.070393+0.001432	test-rmse:0.074498+0.002486
#
# [1]	train-rmse:0.265661+0.000109	test-rmse:0.266324+0.001146
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.152045+0.000384	test-rmse:0.153035+0.000980
# [3]	train-rmse:0.105289+0.000517	test-rmse:0.106754+0.000586
# [4]	train-rmse:0.089288+0.000594	test-rmse:0.091380+0.000805
# [5]	train-rmse:0.084706+0.000593	test-rmse:0.087183+0.001067
# [6]	train-rmse:0.083237+0.000710	test-rmse:0.085945+0.001102
# [7]	train-rmse:0.082571+0.000929	test-rmse:0.085658+0.001126
# [8]	train-rmse:0.082257+0.001067	test-rmse:0.085531+0.001151
# [9]	train-rmse:0.081975+0.001060	test-rmse:0.085342+0.001156
# [10]	train-rmse:0.081713+0.001092	test-rmse:0.085130+0.001386
# [11]	train-rmse:0.081530+0.001187	test-rmse:0.085019+0.001200
# [12]	train-rmse:0.081164+0.001365	test-rmse:0.085077+0.001128
# [13]	train-rmse:0.080826+0.001254	test-rmse:0.085135+0.001276
# [14]	train-rmse:0.080522+0.001260	test-rmse:0.085266+0.001259
# Stopping. Best iteration:
# [11]	train-rmse:0.081530+0.001187	test-rmse:0.085019+0.001200
#
# [1]	train-rmse:0.264774+0.000591	test-rmse:0.265072+0.002865
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.151248+0.000275	test-rmse:0.151944+0.003295
# [3]	train-rmse:0.104462+0.000232	test-rmse:0.105392+0.002557
# [4]	train-rmse:0.088641+0.000307	test-rmse:0.089757+0.001698
# [5]	train-rmse:0.083676+0.000604	test-rmse:0.084952+0.001211
# [6]	train-rmse:0.082180+0.000645	test-rmse:0.084076+0.000685
# [7]	train-rmse:0.081317+0.000785	test-rmse:0.083492+0.000538
# [8]	train-rmse:0.080510+0.000629	test-rmse:0.082818+0.000602
# [9]	train-rmse:0.080223+0.000628	test-rmse:0.082689+0.000535
# [10]	train-rmse:0.079960+0.000652	test-rmse:0.082614+0.000563
# [11]	train-rmse:0.079724+0.000665	test-rmse:0.082645+0.000346
# [12]	train-rmse:0.079337+0.000582	test-rmse:0.082487+0.000177
# [13]	train-rmse:0.079099+0.000559	test-rmse:0.082260+0.000334
# [14]	train-rmse:0.078860+0.000569	test-rmse:0.082450+0.000339
# [15]	train-rmse:0.078675+0.000493	test-rmse:0.082437+0.000349
# [16]	train-rmse:0.078504+0.000478	test-rmse:0.082408+0.000325
# Stopping. Best iteration:
# [13]	train-rmse:0.079099+0.000559	test-rmse:0.082260+0.000334
#
# [1]	train-rmse:0.262392+0.000619	test-rmse:0.262598+0.002145
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.147156+0.000646	test-rmse:0.147575+0.002331
# [3]	train-rmse:0.098632+0.000850	test-rmse:0.099440+0.002584
# [4]	train-rmse:0.081683+0.000945	test-rmse:0.083067+0.002730
# [5]	train-rmse:0.076430+0.001137	test-rmse:0.078517+0.002651
# [6]	train-rmse:0.074663+0.001227	test-rmse:0.077094+0.002623
# [7]	train-rmse:0.073884+0.001282	test-rmse:0.076780+0.002603
# [8]	train-rmse:0.073521+0.001525	test-rmse:0.076591+0.002372
# [9]	train-rmse:0.073126+0.001528	test-rmse:0.076485+0.002154
# [10]	train-rmse:0.072864+0.001649	test-rmse:0.076508+0.002170
# [11]	train-rmse:0.072717+0.001664	test-rmse:0.076616+0.002172
# [12]	train-rmse:0.072603+0.001722	test-rmse:0.076599+0.002166
# Stopping. Best iteration:
# [9]	train-rmse:0.073126+0.001528	test-rmse:0.076485+0.002154
#
# [1]	train-rmse:0.250276+0.000055	test-rmse:0.250276+0.000278
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125402+0.000026	test-rmse:0.125402+0.000304
# [3]	train-rmse:0.063115+0.000012	test-rmse:0.063115+0.000313
# [4]	train-rmse:0.032264+0.000013	test-rmse:0.032274+0.000272
# [5]	train-rmse:0.017394+0.000021	test-rmse:0.017408+0.000232
# [6]	train-rmse:0.010804+0.000020	test-rmse:0.010859+0.000179
# [7]	train-rmse:0.008352+0.000032	test-rmse:0.008446+0.000119
# [8]	train-rmse:0.007590+0.000037	test-rmse:0.007718+0.000098
# [9]	train-rmse:0.007359+0.000040	test-rmse:0.007527+0.000094
# [10]	train-rmse:0.007282+0.000037	test-rmse:0.007465+0.000082
# [11]	train-rmse:0.007241+0.000030	test-rmse:0.007458+0.000073
# [12]	train-rmse:0.007214+0.000029	test-rmse:0.007457+0.000086
# [13]	train-rmse:0.007200+0.000027	test-rmse:0.007451+0.000089
# [14]	train-rmse:0.007178+0.000022	test-rmse:0.007460+0.000078
# [15]	train-rmse:0.007163+0.000019	test-rmse:0.007461+0.000085
# [16]	train-rmse:0.007148+0.000014	test-rmse:0.007466+0.000077
# Stopping. Best iteration:
# [13]	train-rmse:0.007200+0.000027	test-rmse:0.007451+0.000089
#
# [1]	train-rmse:0.250375+0.000039	test-rmse:0.250375+0.000206
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.125599+0.000014	test-rmse:0.125599+0.000219
# [3]	train-rmse:0.063506+0.000004	test-rmse:0.063506+0.000213
# [4]	train-rmse:0.033070+0.000029	test-rmse:0.033053+0.000211
# [5]	train-rmse:0.018845+0.000060	test-rmse:0.018880+0.000123
# [6]	train-rmse:0.012980+0.000099	test-rmse:0.013037+0.000054
# [7]	train-rmse:0.010993+0.000112	test-rmse:0.011103+0.000122
# [8]	train-rmse:0.010409+0.000123	test-rmse:0.010562+0.000180
# [9]	train-rmse:0.010217+0.000111	test-rmse:0.010435+0.000193
# [10]	train-rmse:0.010146+0.000116	test-rmse:0.010386+0.000196
# [11]	train-rmse:0.010094+0.000108	test-rmse:0.010369+0.000221
# [12]	train-rmse:0.010061+0.000107	test-rmse:0.010368+0.000228
# [13]	train-rmse:0.010026+0.000098	test-rmse:0.010366+0.000238
# [14]	train-rmse:0.010012+0.000100	test-rmse:0.010368+0.000243
# [15]	train-rmse:0.009987+0.000098	test-rmse:0.010376+0.000256
# [16]	train-rmse:0.009957+0.000093	test-rmse:0.010371+0.000258
# Stopping. Best iteration:
# [13]	train-rmse:0.010026+0.000098	test-rmse:0.010366+0.000238
#
# [1]	train-rmse:0.250999+0.000089	test-rmse:0.250999+0.000413
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.126839+0.000064	test-rmse:0.126838+0.000468
# [3]	train-rmse:0.065815+0.000069	test-rmse:0.065825+0.000524
# [4]	train-rmse:0.037112+0.000116	test-rmse:0.037240+0.000523
# [5]	train-rmse:0.025126+0.000172	test-rmse:0.025389+0.000459
# [6]	train-rmse:0.021016+0.000184	test-rmse:0.021382+0.000480
# [7]	train-rmse:0.019779+0.000208	test-rmse:0.020219+0.000460
# [8]	train-rmse:0.019395+0.000229	test-rmse:0.019917+0.000446
# [9]	train-rmse:0.019263+0.000245	test-rmse:0.019842+0.000473
# [10]	train-rmse:0.019169+0.000233	test-rmse:0.019829+0.000444
# [11]	train-rmse:0.019104+0.000248	test-rmse:0.019811+0.000452
# [12]	train-rmse:0.019051+0.000247	test-rmse:0.019794+0.000446
# [13]	train-rmse:0.018992+0.000221	test-rmse:0.019780+0.000445
# [14]	train-rmse:0.018924+0.000258	test-rmse:0.019770+0.000421
# [15]	train-rmse:0.018877+0.000283	test-rmse:0.019768+0.000417
# [16]	train-rmse:0.018791+0.000254	test-rmse:0.019810+0.000388
# [17]	train-rmse:0.018720+0.000248	test-rmse:0.019828+0.000394
# [18]	train-rmse:0.018657+0.000261	test-rmse:0.019823+0.000377
# Stopping. Best iteration:
# [15]	train-rmse:0.018877+0.000283	test-rmse:0.019768+0.000417
#
# [1]	train-rmse:0.384259+0.000889	test-rmse:0.384739+0.002500
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.308311+0.001292	test-rmse:0.310829+0.002702
# [3]	train-rmse:0.284216+0.002272	test-rmse:0.287949+0.003354
# [4]	train-rmse:0.276233+0.002401	test-rmse:0.281649+0.004598
# [5]	train-rmse:0.273047+0.002288	test-rmse:0.280254+0.004068
# [6]	train-rmse:0.271896+0.002322	test-rmse:0.279238+0.004444
# [7]	train-rmse:0.270460+0.002324	test-rmse:0.279099+0.004176
# [8]	train-rmse:0.269759+0.002410	test-rmse:0.279784+0.004355
# [9]	train-rmse:0.268723+0.002266	test-rmse:0.279531+0.004745
# [10]	train-rmse:0.268146+0.002406	test-rmse:0.279326+0.004729
# Stopping. Best iteration:
# [7]	train-rmse:0.270460+0.002324	test-rmse:0.279099+0.004176
#
# [1]	train-rmse:0.279042+0.000708	test-rmse:0.278983+0.003110
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 3 rounds.
#
# [2]	train-rmse:0.170838+0.000365	test-rmse:0.171621+0.002222
# [3]	train-rmse:0.129382+0.000716	test-rmse:0.131141+0.001102
# [4]	train-rmse:0.116100+0.000578	test-rmse:0.118539+0.000708
# [5]	train-rmse:0.111302+0.000834	test-rmse:0.114814+0.001435
# [6]	train-rmse:0.109608+0.001026	test-rmse:0.113194+0.001410
# [7]	train-rmse:0.108976+0.001068	test-rmse:0.112780+0.001689
# [8]	train-rmse:0.108495+0.001169	test-rmse:0.112713+0.001744
# [9]	train-rmse:0.108060+0.001275	test-rmse:0.112668+0.001643
# [10]	train-rmse:0.107806+0.001135	test-rmse:0.112340+0.002131
# [11]	train-rmse:0.107331+0.001235	test-rmse:0.111982+0.001839
# [12]	train-rmse:0.107155+0.001238	test-rmse:0.112094+0.001802
# [13]	train-rmse:0.106851+0.001179	test-rmse:0.111925+0.001912
# [14]	train-rmse:0.106552+0.001091	test-rmse:0.111921+0.001779
# [15]	train-rmse:0.106285+0.001152	test-rmse:0.111943+0.001674
# [16]	train-rmse:0.105994+0.001249	test-rmse:0.112141+0.001717
# [17]	train-rmse:0.105800+0.001200	test-rmse:0.112156+0.001705
# Stopping. Best iteration:
# [14]	train-rmse:0.106552+0.001091	test-rmse:0.111921+0.001779

# %%
names(FRI)
dim(FRI)
# Out:
#   [1] "ds"                "county_fips"       "sg_nhd"
#   [4] "state_abbv"        "stay_home"         "PRCP"
#   [7] "TMAX"              "n11"               "n21"
#  [10] "n22"               "n23"               "n31"
#  [13] "n32"               "n33"               "n42"
#  [16] "n44"               "n45"               "n48"
#  [19] "n49"               "n51"               "n52"
#  [22] "n53"               "n54"               "n55"
#  [25] "n56"               "n61"               "n62"
#  [28] "n71"               "n72"               "n81"
#  [31] "n92"               "nNA"               "fb_btvrc"
#  [34] "fb_rnstu"          "n"                 "sg_mcbgv"
#  [37] "ban_gmr"           "log_mcbgv"         "ash_nhd"
#  [40] "ash_rnstu"         "alter_n11"         "alter_n21"
#  [43] "alter_n22"         "alter_n23"         "alter_n31"
#  [46] "alter_n32"         "alter_n33"         "alter_n42"
#  [49] "alter_n44"         "alter_n45"         "alter_n48"
#  [52] "alter_n49"         "alter_n51"         "alter_n52"
#  [55] "alter_n53"         "alter_n54"         "alter_n55"
#  [58] "alter_n56"         "alter_n61"         "alter_n62"
#  [61] "alter_n71"         "alter_n72"         "alter_n81"
#  [64] "alter_n92"         "alter_log_mcbgv"   "alter_ash_nhd"
#  [67] "alter_ash_rnstu"   "alter_nhd"         "alter_mcbgv"
#  [70] "alter_rnstu"       "alter_btvrc"       "alter_sh"
#  [73] "alter_bg"          "alter_bgmr"        "geo_alter_sh"
#  [76] "geo_alter_bg"      "geo_alter_bgmr"    "ash_alter_rnstu"
#  [79] "ash_alter_nhd"     "log_alter_mcbgv"   "grp"
#  [82] "PRCP.fe.r"         "TMAX.fe.r"         "rain"
#  [85] "alter_rain"        "sg_nhd.r"          "stay_home.r"
#  [88] "n11.r"             "n21.r"             "n22.r"
#  [91] "n23.r"             "n31.r"             "n32.r"
#  [94] "n33.r"             "n42.r"             "n44.r"
#  [97] "n45.r"             "n48.r"             "n49.r"
# [100] "n51.r"             "n52.r"             "n53.r"
# [103] "n54.r"             "n55.r"             "n56.r"
# [106] "n61.r"             "n62.r"             "n71.r"
# [109] "n72.r"             "n81.r"             "n92.r"
# [112] "nNA.r"             "fb_btvrc.r"        "fb_rnstu.r"
# [115] "sg_mcbgv.r"        "ban_gmr.r"         "log_mcbgv.r"
# [118] "ash_nhd.r"         "ash_rnstu.r"       "alter_n11.r"
# [121] "alter_n21.r"       "alter_n22.r"       "alter_n23.r"
# [124] "alter_n31.r"       "alter_n32.r"       "alter_n33.r"
# [127] "alter_n42.r"       "alter_n44.r"       "alter_n45.r"
# [130] "alter_n48.r"       "alter_n49.r"       "alter_n51.r"
# [133] "alter_n52.r"       "alter_n53.r"       "alter_n54.r"
# [136] "alter_n55.r"       "alter_n56.r"       "alter_n61.r"
# [139] "alter_n62.r"       "alter_n71.r"       "alter_n72.r"
# [142] "alter_n81.r"       "alter_n92.r"       "alter_log_mcbgv.r"
# [145] "alter_ash_nhd.r"   "alter_ash_rnstu.r" "alter_nhd.r"
# [148] "alter_mcbgv.r"     "alter_rnstu.r"     "alter_btvrc.r"
# [151] "alter_sh.r"        "alter_bg.r"        "alter_bgmr.r"
# [154] "geo_alter_sh.r"    "geo_alter_bg.r"    "geo_alter_bgmr.r"
# [157] "ash_alter_rnstu.r" "ash_alter_nhd.r"   "log_alter_mcbgv.r"
# [160] "rain.r"            "alter_rain.r"
# [1] 122598    161

# %%
### If you need to add a column to the FRI_df after the fact:
### Using current PRCP and TMAX as an example
hf <- gen_helper(panel$PRCP, panel$TMAX)
FRI %>%
    mutate(rain = as.numeric(PRCP > 0)) %>%
    mutate(alter_rain = weightedAlters(., WM, rain)) -> FRI
FRI %>%
    bind_cols(FRIresidualizer(FRI$rain, 'rain', hf), 
              FRIresidualizer(FRI$alter_rain, 'alter_rain', hf)) -> FRI
# Out:
# Joining, by = "county_fips"

# %%
### Simple model
fit <- felm(fb_btvrc.r ~ 0 + ban_gmr.r + geo_alter_bgmr.r + alter_bgmr.r + 
            stay_home.r + geo_alter_sh.r + alter_sh.r | 
            0 | 
            (alter_btvrc.r ~ alter_rain.r) | 0, FRI)
summary(fit)
# Out:
# Call:
#    felm(formula = fb_btvrc.r ~ 0 + ban_gmr.r + geo_alter_bgmr.r +      alter_bgmr.r + stay_home.r + geo_alter_sh.r + alter_sh.r |      0 | (alter_btvrc.r ~ alter_rain.r) | 0, data = FRI)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.38833 -0.01939 -0.00087  0.01815  0.42961
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# ban_gmr.r            -0.007534   0.001512  -4.984 6.24e-07 ***
# geo_alter_bgmr.r     -0.002024   0.002449  -0.826 0.408628
# alter_bgmr.r          0.014928   0.003898   3.829 0.000128 ***
# stay_home.r          -0.027327   0.001843 -14.828  < 2e-16 ***
# geo_alter_sh.r       -0.003683   0.002878  -1.280 0.200679
# alter_sh.r            0.042538   0.004987   8.530  < 2e-16 ***
# `alter_btvrc.r(fit)`  1.497246   0.014776 101.328  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03334 on 122591 degrees of freedom
# Multiple R-squared(full model): 0.569   Adjusted R-squared: 0.5689
# Multiple R-squared(proj model): 0.569   Adjusted R-squared: 0.5689
# F-statistic(full model): 4386 on 7 and 122591 DF, p-value: < 2.2e-16
# F-statistic(proj model):  4390 on 7 and 122591 DF, p-value: < 2.2e-16
# F-statistic(endog. vars):1.027e+04 on 1 and 122591 DF, p-value: < 2.2e-16
