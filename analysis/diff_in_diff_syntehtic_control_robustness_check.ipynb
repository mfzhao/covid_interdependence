# %%
library(cowplot)
library(dplyr)
library(augsynth)
library(stringr)
library(readr)
library(tidyr)
library(lfe)
library(scales)
library(repr)
library(stargazer)
library(doMC)
registerDoMC(12)
# Out:
# ********************************************************
#
# Note: As of version 1.0.0, cowplot does not change the
#
#   default ggplot2 theme anymore. To recover the previous
#
#   behavior, execute:
#   theme_set(theme_cowplot())
#
# ********************************************************
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor
#
#
#
# Please cite as:
#
#
#  Hlavac, Marek (2018). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.2. https://CRAN.R-project.org/package=stargazer
#
#
# Loading required package: foreach
#
# Loading required package: iterators
#
# Loading required package: parallel

# %%
panel <- readRDS('/nfs/sloanlab004/projects/covid_mobility_proj/data/PROCESSED_DATA/data_v2.RData')
load('/nfs/sloanlab004/projects/covid_mobility_proj/data/PROCESSED_DATA/conley_selector_matrix.Rdata')
load('/nfs/sloanlab004/projects/covid_mobility_proj/data/PROCESSED_DATA/social_adj_matrix.RData')
load('/nfs/sloanlab004/projects/covid_mobility_proj/data/PROCESSED_DATA/geo_adjacency_matrix.Rdata')
source('../utils/residualizer+genAlters.R')
source("../utils/labels_and_colors.r")
source('../utils/adjacency_and_cluster_robust_inference.R')
source('../utils/geo_utils.r')
# Out:
# Loaded glmnet 3.0-2
#
#
#
# Attaching package: ‘xgboost’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     slice
#
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
#
# Attaching package: ‘lmtest’
#
#
# The following object is masked from ‘package:lfe’:
#
#     waldtest

# %%
panel %>%
    select(-matches('shiftshare'),
           -matches('iv...'),
           -PRCP, -TMAX) -> panel

# %%
colnames(panel)
# Out:
#  [1] "ds"                "county_fips"       "sg_nhd"
#  [4] "ash_nhd"           "state_abbv"        "stay_home"
#  [7] "fb_btvrc"          "fb_rnstu"          "ash_rnstu"
# [10] "n"                 "sg_mcbgv"          "log_mcbgv"
# [13] "ban_gmr"           "alter_nhd"         "alter_sh"
# [16] "alter_btvrc"       "alter_rnstu"       "alter_mcbgv"
# [19] "alter_bgmr"        "geo_alter_sh"      "geo_alter_bgmr"
# [22] "ash_alter_nhd"     "ash_alter_rnstu"   "log_alter_mcbgv"
# [25] "sg_nhd.r"          "ash_nhd.r"         "stay_home.r"
# [28] "fb_btvrc.r"        "fb_rnstu.r"        "ash_rnstu.r"
# [31] "sg_mcbgv.r"        "log_mcbgv.r"       "ban_gmr.r"
# [34] "alter_nhd.r"       "alter_sh.r"        "alter_btvrc.r"
# [37] "alter_rnstu.r"     "alter_mcbgv.r"     "alter_bgmr.r"
# [40] "geo_alter_sh.r"    "geo_alter_bgmr.r"  "ash_alter_nhd.r"
# [43] "ash_alter_rnstu.r" "log_alter_mcbgv.r"

# %%
panel %>%
    mutate(ds = as.numeric(ds, origin = lubridate::origin)) -> panel

# %%
multisynth(sg_nhd ~ stay_home, county_fips, ds, 
                        panel, fixedeff = T, nu = 1)
# Out:
# Error in asMethod(object): Cholmod error 'problem too large' at file ../Core/cholmod_dense.c, line 105
# Traceback:
#
# 1. multisynth(sg_nhd ~ stay_home, county_fips, ds, panel, fixedeff = T,
#  .     nu = 1)
# 2. multisynth_formatted(wide = wide, relative = T, n_leads = n_leads,
#  .     n_lags = n_lags, nu = nu, lambda = lambda, force = force,
#  .     n_factors = n_factors, scm = scm, time_cohort = time_cohort,
#  .     time_w = F, lambda_t = 0, fit_resids = TRUE, eps_abs = eps_abs,
#  .     eps_rel = eps_rel, verbose = verbose, long_df = long_df,
#  .     ...)
# 3. multisynth_qp(X = bal_mat, trt = wide$trt, mask = wide$mask,
#  .     n_leads = n_leads, n_lags = n_lags, relative = relative,
#  .     nu = nu, lambda = lambda, time_cohort = time_cohort, eps_rel = eps_rel,
#  .     eps_abs = eps_abs, verbose = verbose)
# 4. make_constraint_mats(trt, grps, n_leads, n_lags, Xc, d, n1)
# 5. as.matrix(Matrix::t(A1))
# 6. as.matrix.Matrix(Matrix::t(A1))
# 7. as(x, "matrix")
# 8. asMethod(object)
